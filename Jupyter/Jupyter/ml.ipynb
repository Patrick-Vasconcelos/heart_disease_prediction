# %%
import pandas as pd
from datetime import date
import numpy as np
from sklearn.tree import DecisionTreeClassifier

# %%
pip install pycaret
# Out:
# ...
#   Using cached pycaret-2.3.6-py3-none-any.whl (301 kB)
# ...
#   Using cached kmodes-0.11.1-py2.py3-none-any.whl (19 kB)
# ...
#   Using cached lightgbm-3.3.2-py3-none-win_amd64.whl (1.0 MB)
# ...
#   Using cached pyLDAvis-3.3.1.tar.gz (1.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached PyYAML-5.4.1-cp39-cp39-win_amd64.whl (213 kB)
# ...
#   Using cached cufflinks-0.17.3-py3-none-any.whl
# ...
#   Using cached umap_learn-0.5.2-py3-none-any.whl
# ...
#   Using cached gensim-3.8.3-cp39-cp39-win_amd64.whl
# ...
#   Using cached scipy-1.5.4-cp39-cp39-win_amd64.whl (31.4 MB)
# ...

# %%
# !pip install --upgrade pip setuptools wheel --user
# Out:
# ...
#   Using cached docker-5.0.3-py2.py3-none-any.whl (146 kB)
# ...
#   Using cached waitress-2.0.0-py3-none-any.whl (56 kB)
# ...
#   Using cached databricks_cli-0.16.2-py3-none-any.whl
# ...
#   Using cached querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# ...
#   Using cached GitPython-3.1.26-py3-none-any.whl (180 kB)
# ...
#   Using cached alembic-1.7.5-py3-none-any.whl (209 kB)
# ...
#   Using cached sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached pyLDAvis-3.3.0.tar.gz (1.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
# ...

# %%
df = pd.read_excel('pacientes.xlsx')

# %%
df.head()
# Out:
#    idPaciente                             nome nomeSocial dataNascimento sexo  \
# 0    16366958  PEDRO JACINTO OLIVEIRA SOBRINHO        NaN     1900-01-01  NaN
# 1    16362484             ERICA MESQUILE SOARS        NaN     1900-01-01  NaN
# 2    16366960           LARISSA CALHEIRO GOMES        NaN     1900-01-01  NaN
# 3    11258684            TANIA MARIA DE ARAUJO        NaN     1900-01-01  NaN
# 4    16366962  CAROLINE LOPES ARAGAO DE MACEDO        NaN     1900-01-01  NaN
#
#   codCor estCivil                     email dddCelular telCelular  ...  \
# 0    NaN      NaN                       NaN        NaN        NaN  ...
# 1    NaN      NaN  erikasmesquita@gmail.com         11  993412406  ...
# 2    NaN      NaN                       NaN        NaN        NaN  ...
# 3    NaN      NaN                       NaN        NaN        NaN  ...
# 4    NaN      NaN                       NaN        NaN        NaN  ...
#
# ...

# %%
df = df[['idPaciente','nome', 'dataNascimento', 'sexo', 'cpf', 'bairro','cidade']]

# %%
df.head()
# Out:
#    idPaciente                             nome dataNascimento sexo  \
# 0    16366958  PEDRO JACINTO OLIVEIRA SOBRINHO     1900-01-01  NaN
# 1    16362484             ERICA MESQUILE SOARS     1900-01-01  NaN
# 2    16366960           LARISSA CALHEIRO GOMES     1900-01-01  NaN
# 3    11258684            TANIA MARIA DE ARAUJO     1900-01-01  NaN
# 4    16366962  CAROLINE LOPES ARAGAO DE MACEDO     1900-01-01  NaN
#
#               cpf bairro cidade
# 0             NaN    NaN    NaN
# 1  334.321.178-84    NaN    NaN
# 2             NaN    NaN    NaN
# 3             NaN    NaN    NaN
# 4             NaN    NaN    NaN

# %%
df.isnull().sum()
# Out:
# idPaciente            0
# nome                  0
# dataNascimento        0
# sexo              29181
# cpf               28748
# bairro            30919
# cidade            42493
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80060 entries, 0 to 80059
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   idPaciente      80060 non-null  int64
#  1   nome            80060 non-null  object
#  2   dataNascimento  80060 non-null  datetime64[ns]
#  3   sexo            50879 non-null  object
#  4   cpf             51312 non-null  object
#  5   bairro          49141 non-null  object
#  6   cidade          37567 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 4.3+ MB

# %%
ano_atual = pd.Timestamp.today().year

# %%
df['idade'] = ano_atual - df['dataNascimento'].dt.year

# %%
df.head()
# Out:
#    idPaciente                             nome dataNascimento sexo  \
# 0    16366958  PEDRO JACINTO OLIVEIRA SOBRINHO     1900-01-01  NaN
# 1    16362484             ERICA MESQUILE SOARS     1900-01-01  NaN
# 2    16366960           LARISSA CALHEIRO GOMES     1900-01-01  NaN
# 3    11258684            TANIA MARIA DE ARAUJO     1900-01-01  NaN
# 4    16366962  CAROLINE LOPES ARAGAO DE MACEDO     1900-01-01  NaN
#
#               cpf bairro cidade  idade
# 0             NaN    NaN    NaN    122
# 1  334.321.178-84    NaN    NaN    122
# 2             NaN    NaN    NaN    122
# 3             NaN    NaN    NaN    122
# 4             NaN    NaN    NaN    122

# %%
df
# Out:
#        idPaciente                                               nome  \
# 0        16366958                    PEDRO JACINTO OLIVEIRA SOBRINHO
# 1        16362484                               ERICA MESQUILE SOARS
# 2        16366960                             LARISSA CALHEIRO GOMES
# 3        11258684                              TANIA MARIA DE ARAUJO
# 4        16366962                    CAROLINE LOPES ARAGAO DE MACEDO
# ...           ...                                                ...
# 80055    42277779                                     BIANCA MARINHO
# 80056    42277778  SOFIA MARINHO DE ANDRADE MARTINS DE ALCANTARA ...
# 80057    42277808                                     JAMILE PEIXOTO
# 80058    42277807                              IAN PEIXOTO MAGALHAES
# 80059    42277818                            LUCIANA VIANA RODRIGUES
#
#       dataNascimento sexo             cpf bairro     cidade  idade
# 0         1900-01-01  NaN             NaN    NaN        NaN    122
# ...

# %%
df['sexo'].unique()
# Out:
# array([nan, 'F', 'M', 'm', 'f', '0', 'N', '1', 'n', 'I'], dtype=object)

# %%
filtro = df['sexo'] != 'n'

# %%
df = df[filtro]

# %%
df
# Out:
#        idPaciente                                               nome  \
# 0        16366958                    PEDRO JACINTO OLIVEIRA SOBRINHO
# 1        16362484                               ERICA MESQUILE SOARS
# 2        16366960                             LARISSA CALHEIRO GOMES
# 3        11258684                              TANIA MARIA DE ARAUJO
# 4        16366962                    CAROLINE LOPES ARAGAO DE MACEDO
# ...           ...                                                ...
# 80055    42277779                                     BIANCA MARINHO
# 80056    42277778  SOFIA MARINHO DE ANDRADE MARTINS DE ALCANTARA ...
# 80057    42277808                                     JAMILE PEIXOTO
# 80058    42277807                              IAN PEIXOTO MAGALHAES
# 80059    42277818                            LUCIANA VIANA RODRIGUES
#
#       dataNascimento sexo             cpf bairro     cidade  idade
# 0         1900-01-01  NaN             NaN    NaN        NaN    122
# ...

# %%
df['sexo'].unique()
# Out:
# array([nan, 'F', 'M', 'm', 'f', '0', 'N', '1', 'I'], dtype=object)

# %%
df
# Out:
#        idPaciente                                               nome  \
# 0        16366958                    PEDRO JACINTO OLIVEIRA SOBRINHO
# 1        16362484                               ERICA MESQUILE SOARS
# 2        16366960                             LARISSA CALHEIRO GOMES
# 3        11258684                              TANIA MARIA DE ARAUJO
# 4        16366962                    CAROLINE LOPES ARAGAO DE MACEDO
# ...           ...                                                ...
# 80055    42277779                                     BIANCA MARINHO
# 80056    42277778  SOFIA MARINHO DE ANDRADE MARTINS DE ALCANTARA ...
# 80057    42277808                                     JAMILE PEIXOTO
# 80058    42277807                              IAN PEIXOTO MAGALHAES
# 80059    42277818                            LUCIANA VIANA RODRIGUES
#
#       dataNascimento sexo             cpf bairro     cidade  idade
# 0         1900-01-01  NaN             NaN    NaN        NaN    122
# ...

# %%
df['sexo'] = df['sexo'].map({'m':'M', 'f': 'F', 'F': 'F', 'M' : 'M'})
# Out:
# C:\Users\Qorpo\AppData\Local\Temp/ipykernel_1464/2866852839.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sexo'] = df['sexo'].map({'m':'M', 'f': 'F', 'F': 'F', 'M' : 'M'})

# %%
df.head()
# Out:
#    idPaciente                             nome dataNascimento sexo  \
# 0    16366958  PEDRO JACINTO OLIVEIRA SOBRINHO     1900-01-01  NaN
# 1    16362484             ERICA MESQUILE SOARS     1900-01-01  NaN
# 2    16366960           LARISSA CALHEIRO GOMES     1900-01-01  NaN
# 3    11258684            TANIA MARIA DE ARAUJO     1900-01-01  NaN
# 4    16366962  CAROLINE LOPES ARAGAO DE MACEDO     1900-01-01  NaN
#
#               cpf bairro cidade  idade
# 0             NaN    NaN    NaN    122
# 1  334.321.178-84    NaN    NaN    122
# 2             NaN    NaN    NaN    122
# 3             NaN    NaN    NaN    122
# 4             NaN    NaN    NaN    122

# %%
df['sexo'].unique()
# Out:
# array([nan, 'F', 'M'], dtype=object)

# %%
df
# Out:
#        idPaciente                                               nome  \
# 0        16366958                    PEDRO JACINTO OLIVEIRA SOBRINHO
# 1        16362484                               ERICA MESQUILE SOARS
# 2        16366960                             LARISSA CALHEIRO GOMES
# 3        11258684                              TANIA MARIA DE ARAUJO
# 4        16366962                    CAROLINE LOPES ARAGAO DE MACEDO
# ...           ...                                                ...
# 80055    42277779                                     BIANCA MARINHO
# 80056    42277778  SOFIA MARINHO DE ANDRADE MARTINS DE ALCANTARA ...
# 80057    42277808                                     JAMILE PEIXOTO
# 80058    42277807                              IAN PEIXOTO MAGALHAES
# 80059    42277818                            LUCIANA VIANA RODRIGUES
#
#       dataNascimento sexo             cpf bairro     cidade  idade
# 0         1900-01-01  NaN             NaN    NaN        NaN    122
# ...

# %%
df['idade'].unique()
# Out:
# array([122,  53,  60,  78,  28,  10,  50,  39,  71,  67,  45,  85,  48,
#         35,  33,  58,   6,  24,  42,  56,  44,  41,  70,  80,  92,  40,
#         82,  23,  49,  27,  32,  66,  76,  37,  65,  31,  54,  55,  22,
#         46,  43,  72,  36,  61,  57,  25,  64,  51,  34,  38,  21,  59,
#         75,  73,  77,  29,  13,  62,  15,   5,  11,  83,  47,  86,  81,
#          8,  96,  69, 102,  87,   7,  17,  26,  88,  84,  74,  63,  52,
#         30,  18,  14,  68,  16, 103,   4,  12,  93, 121,  91,  20,  19,
#         79,  90,  99,   9,  89,  97, 104,  94,  95,  98, 100,   3, 112,
#        101, 117,   1,   2, 120, 107], dtype=int64)

# %%
df = df[df['idade'] < 100]

# %%
df['idade'].unique()
# Out:
# array([53, 60, 78, 28, 10, 50, 39, 71, 67, 45, 85, 48, 35, 33, 58,  6, 24,
#        42, 56, 44, 41, 70, 80, 92, 40, 82, 23, 49, 27, 32, 66, 76, 37, 65,
#        31, 54, 55, 22, 46, 43, 72, 36, 61, 57, 25, 64, 51, 34, 38, 21, 59,
#        75, 73, 77, 29, 13, 62, 15,  5, 11, 83, 47, 86, 81,  8, 96, 69, 87,
#         7, 17, 26, 88, 84, 74, 63, 52, 30, 18, 14, 68, 16,  4, 12, 93, 91,
#        20, 19, 79, 90, 99,  9, 89, 97, 94, 95, 98,  3,  1,  2],
#       dtype=int64)

# %%
df
# Out:
#        idPaciente                                               nome  \
# 10       16366972              MARIA ANGELICA CARDOSO MENDES BEZERRA
# 13       16366977                          ROCILENE DE SOUZA MACHADO
# 16       16366984                             INACIO ARIVALDO RABELO
# 20       10960183                            MARIA DE LURDES RIBEIRO
# 22       16366990                            BRENDA DOS SANTOS SILVA
# ...           ...                                                ...
# 80054    42277603                   LUIS CARLOS UCHOA SANDERS JUNIOR
# 80055    42277779                                     BIANCA MARINHO
# 80056    42277778  SOFIA MARINHO DE ANDRADE MARTINS DE ALCANTARA ...
# 80058    42277807                              IAN PEIXOTO MAGALHAES
# 80059    42277818                            LUCIANA VIANA RODRIGUES
#
#       dataNascimento sexo             cpf            bairro     cidade  idade
# ...

# %%
df['bairro'].unique()
# Out:
# array([nan, 'NOVO MONDUBI', 'José Bonifácio', ..., 'AEROPORTO ',
#        'Salesianos', 'SAO GERARDO '], dtype=object)

# %%
df_ = df.drop_duplicates(subset = 'cpf')

# %%
df_
# Out:
#        idPaciente                                               nome  \
# 10       16366972              MARIA ANGELICA CARDOSO MENDES BEZERRA
# 13       16366977                          ROCILENE DE SOUZA MACHADO
# 20       10960183                            MARIA DE LURDES RIBEIRO
# 22       16366990                            BRENDA DOS SANTOS SILVA
# 40       16367015                              ANDREA CRISTINA NUNES
# ...           ...                                                ...
# 80051    42277479                               LUCAS CORREIA CHAVES
# 80052    42277487                      WALMAR DE ANDRADE BRAGA FILHO
# 80054    42277603                   LUIS CARLOS UCHOA SANDERS JUNIOR
# 80055    42277779                                     BIANCA MARINHO
# 80056    42277778  SOFIA MARINHO DE ANDRADE MARTINS DE ALCANTARA ...
#
#       dataNascimento sexo             cpf            bairro     cidade  idade
# ...

# %%
df_.isnull().sum()
# Out:
# idPaciente           0
# nome                 0
# dataNascimento       0
# sexo              1840
# cpf                  1
# bairro            2434
# cidade            5395
# idade                0
# dtype: int64

# %%
df = df_

# %%
df
# Out:
#        idPaciente                                               nome  \
# 10       16366972              MARIA ANGELICA CARDOSO MENDES BEZERRA
# 13       16366977                          ROCILENE DE SOUZA MACHADO
# 20       10960183                            MARIA DE LURDES RIBEIRO
# 22       16366990                            BRENDA DOS SANTOS SILVA
# 40       16367015                              ANDREA CRISTINA NUNES
# ...           ...                                                ...
# 80051    42277479                               LUCAS CORREIA CHAVES
# 80052    42277487                      WALMAR DE ANDRADE BRAGA FILHO
# 80054    42277603                   LUIS CARLOS UCHOA SANDERS JUNIOR
# 80055    42277779                                     BIANCA MARINHO
# 80056    42277778  SOFIA MARINHO DE ANDRADE MARTINS DE ALCANTARA ...
#
#       dataNascimento sexo             cpf            bairro     cidade  idade
# ...

# %%
result = df.groupby('bairro')['bairro'].nunique()

# %% [raw]
# result

# %%
df_2 = df

# %%
df_2.bairro = df.bairro.str.upper()
# Out:
# C:\Users\Qorpo\anaconda3\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_2.cidade = df_2.cidade.str.upper()
# Out:
# C:\Users\Qorpo\AppData\Local\Temp/ipykernel_1464/3430168510.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['cidade'] = df_2.cidade.str.upper()

# %%
df_2
# Out:
#        idPaciente                                               nome  \
# 10       16366972              MARIA ANGELICA CARDOSO MENDES BEZERRA
# 13       16366977                          ROCILENE DE SOUZA MACHADO
# 20       10960183                            MARIA DE LURDES RIBEIRO
# 22       16366990                            BRENDA DOS SANTOS SILVA
# 40       16367015                              ANDREA CRISTINA NUNES
# ...           ...                                                ...
# 80051    42277479                               LUCAS CORREIA CHAVES
# 80052    42277487                      WALMAR DE ANDRADE BRAGA FILHO
# 80054    42277603                   LUIS CARLOS UCHOA SANDERS JUNIOR
# 80055    42277779                                     BIANCA MARINHO
# 80056    42277778  SOFIA MARINHO DE ANDRADE MARTINS DE ALCANTARA ...
#
#       dataNascimento sexo             cpf            bairro     cidade  idade
# ...
